# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('train_v9rqX0R.csv')
tes=pd.read_csv('test_AbJTz2l.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
tes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
train=df.copy()

# %%
train =train.drop('Item_Outlet_Sales',axis=1)

# %%
y=df.Item_Outlet_Sales

# %%
train.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
train.Item_Fat_Content.replace(['Low Fat','Regular','low fat','LF','reg'],['low fat','reg','low fat','low fat','reg'],inplace=True)

# %%
test=tes.copy()

# %%
test.Item_Fat_Content.replace(['Low Fat','Regular','low fat','LF','reg'],['low fat','reg','low fat','low fat','reg'],inplace=True)

# %%
train.Item_Weight.mean()
# Out:
# 12.857645184136183

# %%
train.Item_weight =train.Item_Weight.fillna(12,inplace=True)

# %%
train.Item_Weight.isnull().any()

# %%
test.Item_Weight.mean()
# Out:
# 12.695633368756374

# %%
test.Item_weight =test.Item_Weight.fillna(12,inplace=True)

# %%
features=['Item_Weight','Item_Fat_Content','Item_Visibility','Item_Type','Item_MRP','Outlet_Identifier','Outlet_Type']

# %%
train.Outlet_Location_Type.nunique()
# Out:
# 3

# %%
trainn =train[features]

# %%
testt=test[features]

# %%
x=pd.get_dummies(trainn)

# %%
xtest=pd.get_dummies(testt)

# %%
train.Item_Identifier.nunique()
# Out:
# 1559

# %%
test.Item_Identifier.nunique()
# Out:
# 1543

# %%
x
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Fat_Content_low fat  \
# 0           9.300         0.016047  249.8092                         1
# 1           5.920         0.019278   48.2692                         0
# 2          17.500         0.016760  141.6180                         1
# 3          19.200         0.000000  182.0950                         0
# 4           8.930         0.000000   53.8614                         1
# ...           ...              ...       ...                       ...
# 8518        6.865         0.056783  214.5218                         1
# 8519        8.380         0.046982  108.1570                         0
# 8520       10.600         0.035186   85.1224                         1
# 8521        7.210         0.145221  103.1332                         0
# 8522       14.800         0.044878   75.4670                         1
#
#       Item_Fat_Content_reg  Item_Type_Baking Goods  Item_Type_Breads  \
# ...

# %%
xtest
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Fat_Content_low fat  \
# 0          20.750         0.007565  107.8622                         1
# 1           8.300         0.038428   87.3198                         0
# 2          14.600         0.099575  241.7538                         1
# 3           7.315         0.015388  155.0340                         1
# 4          12.000         0.118599  234.2300                         0
# ...           ...              ...       ...                       ...
# 5676       10.500         0.013496  141.3154                         0
# 5677        7.600         0.142991  169.1448                         0
# 5678       10.000         0.073529  118.7440                         1
# 5679       15.300         0.000000  214.6218                         0
# 5680        9.500         0.104720   79.7960                         0
#
#       Item_Fat_Content_reg  Item_Type_Baking Goods  Item_Type_Breads  \
# ...

# %%
xle=train.Item_Identifier
xtle=test.Item_Identifier

# %%
xtle.nunique()
# Out:
# 1543

# %%
from sklearn.preprocessing import LabelEncoder

encoder=LabelEncoder()
xle=encoder.fit_transform(xle)
xtle=encoder.fit_transform(xtle)

# %%
xtle
# Out:
#       Identifier
# 0           1103
# 1           1067
# 2           1406
# 3            809
# 4           1184
# ...          ...
# 5676         231
# 5677         306
# 5678        1412
# 5679         517
# 5680         987
#
# [5681 rows x 1 columns]

# %%
xle=pd.DataFrame(xle)

# %%
xle.rename(columns={0:'Identifier'},inplace=True)

# %%
xtle=pd.DataFrame(xtle)

# %%
xtle.rename(columns={0:'Identifier'},inplace=True)

# %%
x=pd.concat([x,xle],axis=1)

# %%
xtest=pd.concat([xtest,xtle],axis=1)

# %%
xtest
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Fat_Content_low fat  \
# 0          20.750         0.007565  107.8622                         1
# 1           8.300         0.038428   87.3198                         0
# 2          14.600         0.099575  241.7538                         1
# 3           7.315         0.015388  155.0340                         1
# 4          12.000         0.118599  234.2300                         0
# ...           ...              ...       ...                       ...
# 5676       10.500         0.013496  141.3154                         0
# 5677        7.600         0.142991  169.1448                         0
# 5678       10.000         0.073529  118.7440                         1
# 5679       15.300         0.000000  214.6218                         0
# 5680        9.500         0.104720   79.7960                         0
#
#       Item_Fat_Content_reg  Item_Type_Baking Goods  Item_Type_Breads  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

model=RandomForestRegressor(n_estimators=100, random_state=1)
model.fit(x_train,y_train)
pred=model.predict(x_test)

# %%
from sklearn.tree import DecisionTreeRegressor
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

model1=DecisionTreeRegressor()
model1.fit(x_train, y_train)
pred1=model.predict(x_test)

# %%
logic(y_test,pred1)
# Out:
# 1367826.4026167395

# %%
final=model.predict(xtest)

# %%
from sklearn.metrics import mean_squared_error
logic =mean_squared_error
percent=logic(y_test,pred)

# %%
percent
# Out:
# 1367826.4026167395

# %%
final= pd.DataFrame(predicted)

# %%
final.rename(columns={0:'Item_Outlet_Sales'},inplace=True)

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 1 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Item_Outlet_Sales  5681 non-null   float64
# dtypes: float64(1)
# memory usage: 44.5 KB

# %%
tes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
grp= tes[['Item_Identifier','Outlet_Identifier']]

# %%
grp=pd.concat([grp,final],axis=1)

# %%
grp
# Out:
#      Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              FDW58            OUT049        1578.278900
# 1              FDW14            OUT017        1314.841814
# 2              NCN55            OUT010         536.355164
# 3              FDQ58            OUT017        2486.470048
# 4              FDY38            OUT027        6802.538522
# ...              ...               ...                ...
# 5676           FDB58            OUT046        2555.313768
# 5677           FDD47            OUT018        3290.110622
# 5678           NCO17            OUT045        1902.290470
# 5679           FDJ26            OUT017        5033.880770
# 5680           FDU37            OUT045        1616.109656
#
# [5681 rows x 3 columns]

# %%
grp.to_csv('my_sub.csv',index=False)
